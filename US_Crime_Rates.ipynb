# %% [markdown]
# # United States - Crime Rates - 1960 - 2014

# %% [markdown]
# ### Introduction:
#
# This time you will create a data
#
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/US_Crime_Rates/US_Crime_Rates_1960_2014.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called crime.

# %%
crime = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/US_Crime_Rates/US_Crime_Rates_1960_2014.csv')

# %% [markdown]
# ### Step 4. What is the type of the columns?

# %%
crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year                55 non-null     int64
#  1   Population          55 non-null     int64
#  2   Total               55 non-null     int64
#  3   Violent             55 non-null     int64
#  4   Property            55 non-null     int64
#  5   Murder              55 non-null     int64
#  6   Forcible_Rape       55 non-null     int64
#  7   Robbery             55 non-null     int64
#  8   Aggravated_assault  55 non-null     int64
#  9   Burglary            55 non-null     int64
#  10  Larceny_Theft       55 non-null     int64
#  11  Vehicle_Theft       55 non-null     int64
# dtypes: int64(12)
# memory usage: 5.3 KB

# %%
crime
# Out:
#     Year  Population     Total  Violent  Property  Murder  Forcible_Rape  \
# 0   1960   179323175   3384200   288460   3095700    9110          17190
# 1   1961   182992000   3488000   289390   3198600    8740          17220
# 2   1962   185771000   3752200   301510   3450700    8530          17550
# 3   1963   188483000   4109500   316970   3792500    8640          17650
# 4   1964   191141000   4564600   364220   4200400    9360          21420
# 5   1965   193526000   4739400   387390   4352000    9960          23410
# 6   1966   195576000   5223500   430180   4793300   11040          25820
# 7   1967   197457000   5903400   499930   5403500   12240          27620
# 8   1968   199399000   6720200   595010   6125200   13800          31670
# 9   1969   201385000   7410900   661870   6749000   14760          37170
# 10  1970   203235298   8098000   738820   7359200   16000          37990
# 11  1971   206212000   8588200   816500   7771700   17780          42260
# ...

# %%
crime.columns
# Out:
# Index(['Year', 'Population', 'Total', 'Violent', 'Property', 'Murder',
#        'Forcible_Rape', 'Robbery', 'Aggravated_assault', 'Burglary',
#        'Larceny_Theft', 'Vehicle_Theft'],
#       dtype='object')

# %%
decade1 = crime[:10]
decade2 = crime[10:20]
decade3 = crime[20:30]
decade4 = crime[30:40]
decade5 = crime[40:50]
decade6 = crime[50:55]

# %%
print(decade1['Murder'].sum())
print(decade2['Murder'].sum())
print(decade3['Murder'].sum())
print(decade4['Murder'].sum())
print(decade5['Murder'].sum())
print(decade6['Murder'].sum())
# Out:
# 106180
# 192230
# 206439
# 211664
# 163068
# 72867

# %%
print(decade1['Murder'].sum()/ decade1['Population'].sum())
print(decade2['Murder'].sum()/ decade2['Population'].sum())
print(decade3['Murder'].sum()/ decade3['Population'].sum())
print(decade4['Murder'].sum()/ decade4['Population'].sum())
print(decade5['Murder'].sum()/ decade5['Population'].sum())
print(decade6['Murder'].sum()/ decade6['Population'].sum())
# Out:
# 5.544493562169625e-05
# 9.06235184606924e-05
# 8.705473797561033e-05
# 8.100962716581332e-05
# 5.531536916707801e-05
# 4.640777720849679e-05

# %%
decade1_crime = decade1['Murder'].sum()+decade1['Forcible_Rape'].sum()+decade1['Robbery'].sum()+decade1['Aggravated_assault'].sum()+decade1['Burglary'].sum()+decade1['Larceny_Theft'].sum()+decade1['Vehicle_Theft'].sum()
crime_rate_d1 = decade1_crime / decade1['Population'].sum()
crime_rate_d1
# Out:
# 0.025741233007798858

# %%
decade2_crime = decade2['Murder'].sum()+decade2['Forcible_Rape'].sum()+decade2['Robbery'].sum()+decade2['Aggravated_assault'].sum()+decade2['Burglary'].sum()+decade2['Larceny_Theft'].sum()+decade2['Vehicle_Theft'].sum()
crime_rate_d2 = decade2_crime / decade2['Population'].sum()
decade3_crime = decade3['Murder'].sum()+decade3['Forcible_Rape'].sum()+decade3['Robbery'].sum()+decade3['Aggravated_assault'].sum()+decade3['Burglary'].sum()+decade3['Larceny_Theft'].sum()+decade3['Vehicle_Theft'].sum()
crime_rate_d3 = decade3_crime / decade3['Population'].sum()
decade4_crime = decade4['Murder'].sum()+decade4['Forcible_Rape'].sum()+decade4['Robbery'].sum()+decade4['Aggravated_assault'].sum()+decade4['Burglary'].sum()+decade4['Larceny_Theft'].sum()+decade4['Vehicle_Theft'].sum()
crime_rate_d4 = decade4_crime / decade4['Population'].sum()
decade5_crime = decade5['Murder'].sum()+decade5['Forcible_Rape'].sum()+decade5['Robbery'].sum()+decade5['Aggravated_assault'].sum()+decade5['Burglary'].sum()+decade5['Larceny_Theft'].sum()+decade5['Vehicle_Theft'].sum()
crime_rate_d5 = decade5_crime / decade5['Population'].sum()
decade6_crime = decade6['Murder'].sum()+decade6['Forcible_Rape'].sum()+decade6['Robbery'].sum()+decade6['Aggravated_assault'].sum()+decade6['Burglary'].sum()+decade6['Larceny_Theft'].sum()+decade6['Vehicle_Theft'].sum()
crime_rate_d6 = decade6_crime / decade6['Population'].sum()

# %%
print(crime_rate_d1)
print(crime_rate_d2)
print(crime_rate_d3)
print(crime_rate_d4)
print(crime_rate_d5)
print(crime_rate_d6)
# Out:
# 0.025741233007798858
# 0.04761076705985331
# 0.055294395722593565
# 0.05227375331810268
# 0.03898153387608911
# 0.0319102906376482

# %%
decade1.sum()[6:]
# Out:
# Forcible_Rape           236720
# Robbery                1633510
# Aggravated_assault     2158520
# Burglary              13321100
# Larceny_Theft         26547700
# Vehicle_Theft          5292100
# dtype: int64

# %% [markdown]
# ##### Have you noticed that the type of Year is int64. But pandas has a different type to work with Time Series. Let's see it now.
#
# ### Step 5. Convert the type of the column Year to datetime64

# %%
crime.Year = pd.to_datetime(crime.Year)

# %% [markdown]
# ### Step 6. Set the Year column as the index of the dataframe

# %%
crime.set_index('Year', inplace= True)

# %%
crime.reset_index('Year', inplace= True)

# %% [markdown]
# ### Step 7. Delete the Total column

# %%
crime.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-74ddedadafe1> in <module>
# ----> 1 crime.shape
#
# NameError: name 'crime' is not defined

# %% [markdown]
# ### Step 8. Group the year by decades and sum the values
#
# #### Pay attention to the Population column number, summing this column is a mistake

# %% [markdown]
# ### Step 9. What is the most dangerous decade to live in the US?

# %%
## the most dangerous decade is the third decade

# %%
plt.plot(decade1['Year'], decade1['Murder'], color = 'blue')
plt.plot(decade2['Year'], decade2['Murder'], color = 'green')
plt.plot(decade3['Year'], decade3['Murder'], color = 'purple')
plt.plot(decade4['Year'], decade4['Murder'], color = 'black')
plt.plot(decade5['Year'], decade5['Murder'], color = 'yellow')
plt.plot(decade6['Year'], decade6['Murder'], color = 'grey')
plt.show()
